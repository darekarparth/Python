# %%
#define class
class smartPhone:
    #contructor
    def __init__(self, device, brand):
        self.device = device
        self.brand = brand
    
     #method of class
    def description(self):
        return f"{self.device} of {self.brand} supports Android 14"

#creating object of class
phoneObj = smartPhone("Cellphone", "Apple")
print(phoneObj.description())
# Out:
# Cellphone of Apple supports Android 14

# %%
class Employee:
    "Common base class for employees"
    empCount = 0
    
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
        Employee.empCount+= 1
        
    # def displayCount(self):
    #     print("Total Employee %d" %Employee.empCount)
        
    def displayEmployee(self):
        print("Name:", self.name, "Salary:", self.salary)
        
#This would create first and second object of Employee class
emp1 = Employee("Zara", 2000)
emp2 = Employee("Manni", 5000)

emp1.displayEmployee()
emp2.displayEmployee()

print("Total Employee %d" %Employee.empCount)
#emp1.displayCount()
# Out:
# Name: Zara Salary: 2000
# Name: Manni Salary: 5000
# Total Employee 2

# %%
#Built-In Class Attributes in Python

class Employee:
     #Common base class for all employees'
    empCount = 0
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
        Employee.empCount += 1
    
    def displayCount(self):
        print ("Total Employee %d" % Employee.empCount)
    
    def displayEmployee(self):
        print ("Name : ", self.name,  ", Salary: ", self.salary)

print ("Employee.__doc__:", Employee.__doc__)
print ("Employee.__name__:", Employee.__name__)
print ("Employee.__module__:", Employee.__module__)
print ("Employee.__bases__:", Employee.__bases__)
print ("Employee.__dict__:", Employee.__dict__)
# Out:
# Employee.__doc__: None
# Employee.__name__: Employee
# Employee.__module__: __main__
# Employee.__bases__: (<class 'object'>,)
# Employee.__dict__: {'__module__': '__main__', 'empCount': 0, '__init__': <function Employee.__init__ at 0x0000027077EA3880>, 'displayCount': <function Employee.displayCount at 0x0000027077EA39C0>, 'displayEmployee': <function Employee.displayEmployee at 0x0000027077EA34C0>, '__dict__': <attribute '__dict__' of 'Employee' objects>, '__weakref__': <attribute '__weakref__' of 'Employee' objects>, '__doc__': None}

# %%
#Class Attributes
#Simple class
class Employee:
    name = 'Parth'
    age = 26

emp = Employee()
#Accessing class attributes
print('Name of the Employee', emp.name)
print('Age of the Employee', emp.age)
# Out:
# Name of the Employee Parth
# Age of the Employee 26

# %%
#Modifying class attributes
class Employee:
    empCount = 0
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
        Employee.empCount+=1
        
        print("Name:", self.name, "Salary:", self.salary)
        print("Employee Count:", Employee.empCount)
        
emp1 = Employee("Parth", 1000000000)
print()
emp2 = Employee("Raj", 50000000)
# Out:
# Name: Parth Salary: 1000000000
# Employee Count: 1
# Name: Raj Salary: 50000000
# Employee Count: 2

# %%
#Instance Attributes
class Student:
    def __init__(self, name, grade):
        self.__name = name
        self.__grade = grade
        print("Name:", self.__name, "Grade:", self.__grade)
        
student1 = Student("Parth", 100)
student2 = Student("Vaishnavi", 200)
# Out:
# Name: Parth Grade: 100
# Name: Vaishnavi Grade: 200
