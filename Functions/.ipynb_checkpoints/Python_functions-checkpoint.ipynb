# %%
def greeting(): // Function Defined
    print('Hello world')
    return

greeting() // function called
# Out:
# Hello world

# %%
def giveOut(str):
    print(str)
    return

giveOut("I am first to call user defined function")
giveOut("Again second call to the same function")
# Out:
# I am first to call user defined function
# Again second call to the same function

# %%
def testFunction(arg):
    print("ID inside the function", id(arg))
    return

var = 'Hello'
print("ID before passing", id(var))

testFunction(var)
# Out:
# ID before passing 2941052903472
# ID inside the function 2941052903472

# %%
def testFunction1(arg):
    print("ID inside the function", id(arg))
    arg = arg + 1
    print("new object after increment", arg, id(arg) )
    return 
var = 10
print ("ID before passing:", id(var))
testFunction1(var)
print ("value after function call", var)
# Out:
# ID before passing: 140712501351496
# ID inside the function 140712501351496
# new object after increment 11 140712501351528
# value after function call 10

# %%
def testfunction(arg):
    print ("Inside function:",arg)
    print ("ID inside the function:", id(arg))
    arg.append(100)
    return

var=[10, 20, 30, 40]
print ("ID before passing:", id(var))
testfunction(var)
print ("list after function call", var)
# Out:
# ID before passing: 3124105217984
# Inside function: [10, 20, 30, 40]
# ID inside the function: 3124105217984
# list after function call [10, 20, 30, 40, 100]

# %%
def greetings(name):
    print ("Hello {}".format(name))
    return
   
greetings("Samay")
greetings("Pratima")
greetings("Steven")
# Out:
# Hello Samay
# Hello Pratima
# Hello Steven

# %%
# Function definition is here
def printme( str ):
    "This prints a passed string into this function"
    print(str)
    return;

# Now you can call printme function
printme()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       5     return;
#       7 # Now you can call printme function
# ----> 8 printme()
#
# TypeError: printme() missing 1 required positional argument: 'str'

# %%
def add(x,y):
    z = x+y
    print ("x={} y={} x+y={}".format(x,y,z))
    return
a = 10
b = 20
add(a, b)
# Out:
# x=10 y=20 x+y=30

# %%
def printme( str ):
    "This prints a passed string into this function"
    print (str)
    return;

# Now you can call printme function
printme(str = "My string")
# Out:
# My string

# %%
def printinfo( name, age ):
    "This prints a passed info into this function"
    print ("Name: ", name)
    print ("Age ", age)
    return;

# Now you can call printinfo function
printinfo( age=50, name="miki" )
# Out:
# Name:  miki
# Age  50

# %%
def printinfo( name, age = 35 ):
    "This prints a passed info into this function"
    print ("Name: ", name)
    print ("Age ", age)
    return;

# Now you can call printinfo function
printinfo( age=50, name="miki" )
printinfo( name="miki" )
# Out:
# Name:  miki
# Age  50
# Name:  miki
# Age  35

# %%
def posFun(x, y, /, z):
    print(x + y + z)

print("Evaluating positional-only arguments: ")
posFun(33, 22, z=11)
# Out:
# Evaluating positional-only arguments:
# 66

# %%
def posFun(*, num1, num2, num3):
    print(num1 * num2 * num3)

print("Evaluating keyword-only arguments: ")
posFun(num1=6, num2=8, num3=5)
# Out:
# Evaluating keyword-only arguments:
# 240

# %%
def printinfo( arg1, *vartuple ):
    "This prints a variable passed arguments"
    print ("Output is: ")
    print (arg1)
    for var in vartuple:
        print (var)
    return;

# Now you can call printinfo function
printinfo( 10 )
printinfo( 70, 60, 50 )
# Out:
# Output is:
# 10
# Output is:
# 70
# 60
# 50

# %%
def add(x,y):
   z=x+y
   return z
a=10
b=20
result = add(a,b)
print ("a = {} b = {} a+b = {}".format(a, b, result))
# Out:
# a = 10 b = 20 a+b = 30

# %%
#Anonymous Function
# Function definition is here
sum = lambda arg1, arg2: arg1 + arg2;

# Now you can call sum as a function
print ("Value of total : ", sum( 10, 20 ))
print ("Value of total : ", sum( 20, 20 ))
# Out:
# Value of total :  30
# Value of total :  40

# %%
total = 0; # This is global variable.
# Function definition is here
def sum( arg1, arg2 ):
   # Add both the parameters and return them."
    total = arg1 + arg2; # Here total is local variable.
    print ("Inside the function local total : ", total)
    return;

# Now you can call sum function
sum( 10, 20 );
print ("Outside the function global total : ", total)
# Out:
# Inside the function local total :  30
# Outside the function global total :  0

# %%
#global variables
name = 'TutorialsPoint'
marks = 50
def myfunction():
   # accessing inside the function
    print("name:", name)
    print("marks:", marks)
    return;
# function call
myfunction()
# Out:
# name: TutorialsPoint
# marks: 50

# %%
#Local Variables
def myfunction():
    a = 10
    b = 20
    print("variable a:", a)
    print("variable b:", b)
    return a+b
   
print (myfunction())
# Out:
# variable a: 10
# variable b: 20
# 30

# %%
def yourfunction():
    a = 5
    b = 6 
    # nested function
    def myfunction():
      # nonlocal function 
        nonlocal a
        nonlocal b
        a = 10
        b = 20 
        print("variable a:", a)
        print("variable b:", b)
        return a+b
    print (myfunction())
yourfunction()
# Out:
# variable a: 10
# variable b: 20
# 30

# %%
#Function Annotations
def myfunction(a: int, b: int):
    c = a+b
    return c
   
print (myfunction(10,20))
print (myfunction("Hello ", "Python"))
# Out:
# 30
# Hello Python

# %%
#Function Annotations With Return Type
def myfunction(a: int, b: int) -> int:
    c = a+b
    return c
print(myfunction(56,88))
print(myfunction.__annotations__)
# Out:
# 144
# {'a': <class 'int'>, 'b': <class 'int'>, 'return': <class 'int'>}
